# %% [markdown]
# **Part 1**

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
table=df[0]
table
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# 7           M8A      Not assigned
# 8           M9A         Etobicoke
# 9           M1B       Scarborough
# 10          M2B      Not assigned
# 11          M3B        North York
# 12          M4B         East York
# 13          M5B  Downtown Toronto
# 14          M6B        North York
# 15          M7B      Not assigned
# 16          M8B      Not assigned
# 17          M9B         Etobicoke
# 18          M1C       Scarborough
# 19          M2C      Not assigned
# 20          M3C        North York
# 21          M4C         East York
# 22          M5C  Downtown Toronto
# 23          M6C              York
# 24          M7C      Not assigned
# 25          M8C      Not assigned
# ...

# %%
new=table[table.Borough != 'Not assigned']
new
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# 8           M9A         Etobicoke
# 9           M1B       Scarborough
# 11          M3B        North York
# 12          M4B         East York
# 13          M5B  Downtown Toronto
# 14          M6B        North York
# 17          M9B         Etobicoke
# 18          M1C       Scarborough
# 20          M3C        North York
# 21          M4C         East York
# 22          M5C  Downtown Toronto
# 23          M6C              York
# 26          M9C         Etobicoke
# 27          M1E       Scarborough
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 32          M6E              York
# 36          M1G       Scarborough
# 39          M4G         East York
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# ...

# %% [markdown]
# Each postal code appears only once so all neighbourhoods within a postal code area are combined into one row

# %%
new.groupby('Postal Code').count()
# Out:
#              Borough  Neighborhood
# Postal Code
# M1B                1             1
# M1C                1             1
# M1E                1             1
# M1G                1             1
# M1H                1             1
# M1J                1             1
# M1K                1             1
# M1L                1             1
# M1M                1             1
# M1N                1             1
# M1P                1             1
# M1R                1             1
# M1S                1             1
# M1T                1             1
# M1V                1             1
# M1W                1             1
# M1X                1             1
# M2H                1             1
# M2J                1             1
# M2K                1             1
# M2L                1             1
# M2M                1             1
# M2N                1             1
# M2P                1             1
# M2R                1             1
# ...

# %%
new.shape
# Out:
# (103, 3)

# %% [markdown]
# **Part 2**

# %%
import pandas as pd
import numpy as np

# %%
geo=pd.read_csv("http://cocl.us/Geospatial_data")
geo
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# ...

# %%
merged=pd.merge(new, geo, on='Postal Code', how='left')
merged
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %% [markdown]
# **Part 3**

# %%
import numpy as np

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 

import requests
from pandas.io.json import json_normalize 

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium 

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %% [markdown]
# Use geopy library to get the latitude and longitude values of Toronto:

# %%
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# Create a map of Toronto with neighborhoods superimposed on top:

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(new['Latitude'], new['Longitude'], new['Borough'], new['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-157-b16d01dcda99> in <module>
# ...

# %% [markdown]
# To simplify, segment and cluster only the neighbourhoods in e.g. Central Toronto.
# Slice the original dataframe and create a new dataframe of the Central Toronto data:

# %%
centraltoronto = neighborhoods[neighborhoods['Borough'] == 'Central Toronto'].reset_index(drop=True)
centraltoronto.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-14e00d653eb8> in <module>
# ----> 1 centraltoronto = neighborhoods[neighborhoods['Borough'] == 'Central Toronto'].reset_index(drop=True)
#       2 centraltoronto.head()
#
# NameError: name 'neighborhoods' is not defined

# %% [markdown]
# Get geographical co-ordinates of Central Toronto:

# %%
address = 'Central Toronto, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Central Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Central Toronto are 43.6534817, -79.3839347.

# %%
map_centraltoronto = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(centraltoronto['Latitude'], centraltoronto['Longitude'], centraltoronto['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_centraltoronto)  
    
map_centraltoronto
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-5c1aefcc215d> in <module>
#       1 map_centraltoronto = folium.Map(location=[latitude, longitude], zoom_start=11)
#       2
# ----> 3 for lat, lng, label in zip(centraltoronto['Latitude'], centraltoronto['Longitude'], centraltoronto['Neighborhood']):
#       4     label = folium.Popup(label, parse_html=True)
#       5     folium.CircleMarker(
#
# NameError: name 'centraltoronto' is not defined

# %% [markdown]
# Utilise the Foursquare API to explore the neighbourhoods and segment them. Define Foursquare Credentials and Version:

# %%
CLIENT_ID = 'your-client-ID' 
CLIENT_SECRET = 'your-client-secret' 
VERSION = '20180605' 

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: your-client-ID
# CLIENT_SECRET:your-client-secret

# %% [markdown]
# Explore first neighbourhood in dataframe. Get the neighbourhood's name:

# %%
centraltoronto.loc[0, 'Neighborhood']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-4bf3e44942aa> in <module>
# ----> 1 centraltoronto.loc[0, 'Neighborhood']
#
# NameError: name 'centraltoronto' is not defined

# %% [markdown]
# Get the neighbourhood's latitude and longitude:

# %%
neighborhood_latitude = centraltoronto.loc[0, 'Latitude'] 
neighborhood_longitude = centraltoronto.loc[0, 'Longitude'] 

neighborhood_name = centraltoronto.loc[0, 'Neighborhood']

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-7460b9acf4ba> in <module>
# ----> 1 neighborhood_latitude = centraltoronto.loc[0, 'Latitude']
#       2 neighborhood_longitude = centraltoronto.loc[0, 'Longitude']
#       3
#       4 neighborhood_name = centraltoronto.loc[0, 'Neighborhood']
#       5
#
# NameError: name 'centraltoronto' is not defined

# %% [markdown]
# Get the top 100 venues in the neighbourhood within a radius of 500 metres. GET request URL:

# %%
LIMIT = 100
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-1ccf6e543e89> in <module>
#       5     CLIENT_SECRET,
#       6     VERSION,
# ----> 7     neighborhood_latitude,
#       8     neighborhood_longitude,
#       9     radius,
#
# NameError: name 'neighborhood_latitude' is not defined

# %% [markdown]
# Send GET request and examine results

# %%
results = requests.get(url).json()
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-f048ffce0a17> in <module>
# ----> 1 results = requests.get(url).json()
#       2 results
#
# NameError: name 'url' is not defined

# %% [markdown]
# get_category_function from the Foursquare lab

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Clean the json and structure it into a pandas dataframe

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) 

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-a608756be7e4> in <module>
# ----> 1 venues = results['response']['groups'][0]['items']
#       2
#       3 nearby_venues = json_normalize(venues)
#       4
#       5 filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
#
# NameError: name 'results' is not defined

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-8d3c8155afff> in <module>
# ----> 1 print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
#
# NameError: name 'nearby_venues' is not defined

# %% [markdown]
# Create a function to repeat the same process to all the neighbourhoods in Central Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
 
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
centraltoronto_venues = getNearbyVenues(names=centraltoronto['Neighborhood'],
                                   latitudes=centraltoronto['Latitude'],
                                   longitudes=centraltoronto['Longitude']
                                  )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-143-c7f67593e104> in <module>
# ----> 1 centraltoronto_venues = getNearbyVenues(names=centraltoronto['Neighborhood'],
#       2                                    latitudes=centraltoronto['Latitude'],
#       3                                    longitudes=centraltoronto['Longitude']
#       4                                   )
#
# NameError: name 'centraltoronto' is not defined

# %%
print(centraltoronto_venues.shape)
centraltoronto_venues.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-c4cdee917870> in <module>
# ----> 1 print(centraltoronto_venues.shape)
#       2 centraltoronto_venues.head()
#
# NameError: name 'centraltoronto_venues' is not defined

# %% [markdown]
# venues for each neighbourhood:

# %%
centraltoronto_venues.groupby('Neighborhood').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-5ff6d1df9320> in <module>
# ----> 1 centraltoronto_venues.groupby('Neighborhood').count()
#
# NameError: name 'centraltoronto_venues' is not defined

# %% [markdown]
# number of unique categories from all the returned venues:

# %%
print('There are {} uniques categories.'.format(len(centraltoronto_venues['Venue Category'].unique())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-9e78c1a91e73> in <module>
# ----> 1 print('There are {} uniques categories.'.format(len(centraltoronto_venues['Venue Category'].unique())))
#
# NameError: name 'centraltoronto_venues' is not defined

# %% [markdown]
# analyse each neighbourhood

# %%
centraltoronto_onehot = pd.get_dummies(centraltoronto_venues[['Venue Category']], prefix="", prefix_sep="")

centraltoronto_onehot['Neighborhood'] = centraltoronto_venues['Neighborhood'] 

fixed_columns = [centraltoronto_onehot.columns[-1]] + list(centraltoronto_onehot.columns[:-1])
centraltoronto_onehot = centraltoronto_onehot[fixed_columns]

centraltoronto_onehot.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-983fd8b90281> in <module>
# ----> 1 centraltoronto_onehot = pd.get_dummies(centraltoronto_venues[['Venue Category']], prefix="", prefix_sep="")
#       2
#       3 centraltoronto_onehot['Neighborhood'] = centraltoronto_venues['Neighborhood']
#       4
#       5 fixed_columns = [centraltoronto_onehot.columns[-1]] + list(centraltoronto_onehot.columns[:-1])
#
# NameError: name 'centraltoronto_venues' is not defined

# %%
centraltoronto_onehot.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-de4f693aba93> in <module>
# ----> 1 centraltoronto_onehot.shape
#
# NameError: name 'centraltoronto_onehot' is not defined

# %%
centraltoronto_grouped = centraltoronto_onehot.groupby('Neighborhood').mean().reset_index()
centraltoronto_grouped
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-6cb601508ea8> in <module>
# ----> 1 centraltoronto_grouped = centraltoronto_onehot.groupby('Neighborhood').mean().reset_index()
#       2 centraltoronto_grouped
#
# NameError: name 'centraltoronto_onehot' is not defined

# %%
centraltoronto_grouped.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-83c278c1d237> in <module>
# ----> 1 centraltoronto_grouped.shape
#
# NameError: name 'centraltoronto_grouped' is not defined

# %% [markdown]
# each neighbourhood with top 5 most common venues:

# %%
num_top_venues = 5

for hood in centraltoronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = centraltoronto_grouped[centraltoronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-151-14e46b6c8fe1> in <module>
#       1 num_top_venues = 5
#       2
# ----> 3 for hood in centraltoronto_grouped['Neighborhood']:
#       4     print("----"+hood+"----")
#       5     temp = centraltoronto_grouped[centraltoronto_grouped['Neighborhood'] == hood].T.reset_index()
#
# NameError: name 'centraltoronto_grouped' is not defined

# %% [markdown]
# put into pandas dataframe

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# top 10 venues per neighbourhood

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = centraltoronto_grouped['Neighborhood']

for ind in np.arange(manhattan_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(centraltoronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-153-dccf57300faa> in <module>
#      11
#      12 neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
# ---> 13 neighborhoods_venues_sorted['Neighborhood'] = centraltoronto_grouped['Neighborhood']
#      14
#      15 for ind in np.arange(manhattan_grouped.shape[0]):
#
# NameError: name 'centraltoronto_grouped' is not defined

# %% [markdown]
# Cluster neighbourhoods

# %%
kclusters = 5

centraltoronto_grouped_clustering = centraltoronto_grouped.drop('Neighborhood', 1)

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(centraltoronto_grouped_clustering)

kmeans.labels_[0:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-154-e612e26122e4> in <module>
#       1 kclusters = 5
#       2
# ----> 3 centraltoronto_grouped_clustering = centraltoronto_grouped.drop('Neighborhood', 1)
#       4
#       5 kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(centraltoronto_grouped_clustering)
#
# NameError: name 'centraltoronto_grouped' is not defined

# %% [markdown]
# new dataframe

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

centraltoronto_merged = centraltoronto

centraltoronto_merged = centraltoronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

centraltoronto_merged.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-155-717ce598ee01> in <module>
# ----> 1 neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
#       2
#       3 centraltoronto_merged = centraltoronto
#       4
#       5 centraltoronto_merged = centraltoronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
#
# NameError: name 'kmeans' is not defined

# %% [markdown]
# Visualise resulting clusters

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster in zip(centraltoronto_merged['Latitude'], centraltoronto_merged['Longitude'], centraltoronto_merged['Neighborhood'], centraltoronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-156-e38447708153> in <module>
#       7
#       8 markers_colors = []
# ----> 9 for lat, lon, poi, cluster in zip(centraltoronto_merged['Latitude'], centraltoronto_merged['Longitude'], centraltoronto_merged['Neighborhood'], centraltoronto_merged['Cluster Labels']):
#      10     label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
#      11     folium.CircleMarker(
#
# NameError: name 'centraltoronto_merged' is not defined
